# %%
import pandas as pd

weather = pd.read_csv("/content/jfk.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2024-06-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  11.86
# 2024-06-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  10.96
# 2024-06-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  11.18
# 2024-06-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   6.71
# 2024-06-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  12.53
#
# ...

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.516786
# ACSH       0.516735
# AWND       0.258569
# FMTM       0.491205
# PGTM       0.383405
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000101
# TAVG       0.659514
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998442
# WDF1       0.516987
# WDF2       0.484823
# WDF5       0.488994
# WDFG       0.742637
# WDFM       0.999950
# WESD       0.694894
# WSF1       0.516836
# WSF2       0.484823
# WSF5       0.489044
# WSFG       0.624937
# WSFM       0.999950
# WT01       0.630365
# WT02       0.934717
# WT03       0.933209
# WT04       0.982611
# WT05       0.981707
# WT06       0.990853
# WT07       0.994572
# WT08       0.801488
# WT09       0.992964
# WT11       0.999296
# WT13       0.890190
# WT14       0.955423
# WT15       0.997889
# WT16       0.669464
# WT17       0.996985
# WT18       0.941351
# WT19       0.999950
# WT21       0.999749
# WT22       0.997537
# WV01       0.999950
# ...

# %%
valid_columns = weather.columns[null_pct < .05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2024-06-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-06-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-06-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-06-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.04   0.0   0.0
# 2024-06-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# ...

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2024-06-14', '2024-06-15', '2024-06-16', '2024-06-17', '2024-06-18',
#        '2024-06-19', '2024-06-20', '2024-06-21', '2024-06-22', '2024-06-23'],
#       dtype='object', name='DATE', length=19898)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024    175
# Name: count, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2024-06-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-06-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-06-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-06-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.04   0.0   0.0
# 2024-06-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# ...

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2024-06-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-06-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-06-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-06-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.04   0.0   0.0
# 2024-06-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# ...

# %%
from sklearn.linear_model import Ridge

model = Ridge(alpha = 0.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
def train_model(weather, model, predictors, start=3650, step=90):
    all_predictions = []

    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]

        model.fit(train[predictors], train["target"])
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        all_predictions.append(combined)

    return pd.concat(all_predictions)

# %%
predictions = train_model(weather, model, predictors)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.1366270178826

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2007-03-26    78.0   49.744725  28.255275
# 1999-01-02    53.0   25.911898  27.088102
# 1998-03-26    80.0   53.033957  26.966043
# 1985-04-18    84.0   57.071179  26.928821
# 1990-03-12    85.0   58.144310  26.855690
# ...            ...         ...        ...
# 2006-08-20    88.0   88.002937   0.002937
# 2019-03-01    40.0   40.002460   0.002460
# 1992-06-11    76.0   76.001641   0.001641
# 2011-09-16    66.0   66.000831   0.000831
# 2014-03-25    39.0   38.999920   0.000080
#
# [16248 rows x 3 columns]

# %%
pd.Series(model.coef_, index=predictors)
# Out:
# prcp   -1.236110
# snow   -0.407827
# snwd    0.053422
# tmax    0.447413
# tmin    0.517302
# dtype: float64

# %%
def percentage_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = percentage_diff(weather[label], weather[col])
    return weather

rolling_horizons = [3, 14]
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2024-06-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-06-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-06-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-06-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.04   0.0   0.0
# 2024-06-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather = weather.iloc[14:,:]
weather = weather.fillna(0)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictions = train_model(weather, model, predictors)
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 4.789511502083012

# %%
mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 37.5426404851592

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1990-03-12    85.0   54.344781  30.655219
# 2007-03-26    78.0   49.975934  28.024066
# 1998-03-26    80.0   52.017642  27.982358
# 2003-04-15    86.0   59.421162  26.578838
# 1985-04-18    84.0   58.526667  25.473333
# ...            ...         ...        ...
# 2013-09-29    72.0   71.996846   0.003154
# 2001-12-02    53.0   52.998201   0.001799
# 1999-09-28    77.0   76.998730   0.001270
# 1985-08-03    80.0   80.000664   0.000664
# 1996-11-03    53.0   52.999354   0.000646
#
# [16220 rows x 3 columns]

# %%
weather.loc["1990-03-07": "1990-03-17"]
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1990-03-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   2.0
# 1990-03-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   1.0
# 1990-03-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 1990-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
# ...

# %%
predictions["diff"].round().value_counts().sort_index()
# Out:
# diff
# 0.0     1184
# 1.0     2250
# 2.0     2067
# 3.0     1904
# 4.0     1659
# 5.0     1439
# 6.0     1199
# 7.0     1036
# 8.0      836
# 9.0      702
# 10.0     532
# 11.0     390
# 12.0     316
# 13.0     208
# 14.0     151
# 15.0      98
# 16.0      80
# 17.0      54
# 18.0      36
# 19.0      25
# 20.0      13
# 21.0      13
# 22.0      10
# 23.0       7
# 24.0       4
# 25.0       3
# 27.0       1
# 28.0       2
# 31.0       1
# Name: count, dtype: int64

# %%
(predictions["diff"].round().value_counts().sort_index() / predictions.shape[0]).plot()
# Out:
# <Axes: xlabel='diff'>

# %%
predictions
# Out:
#             actual  prediction      diff
# DATE
# 1980-01-27    37.0   38.123923  1.123923
# 1980-01-28    31.0   39.569226  8.569226
# 1980-01-29    28.0   35.953865  7.953865
# 1980-01-30    26.0   31.583613  5.583613
# 1980-01-31    24.0   29.844075  5.844075
# ...            ...         ...       ...
# 2024-06-19    84.0   81.258416  2.741584
# 2024-06-20    91.0   81.882619  9.117381
# 2024-06-21    87.0   84.687209  2.312791
# 2024-06-22    85.0   84.840165  0.159835
# 2024-06-23    85.0   83.745575  1.254425
#
# [16220 rows x 3 columns]

# %%
from matplotlib import pyplot as plt
predictions['prediction'].plot(kind='hist', bins=20, title='prediction')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
predictions['actual'].plot(kind='hist', bins=20, title='actual')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
predictions['diff'].plot(kind='hist', bins=20, title='diff')
plt.gca().spines[['top', 'right',]].set_visible(False)
